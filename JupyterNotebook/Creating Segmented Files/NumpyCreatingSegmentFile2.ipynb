# %% [markdown]
# # Creating the Segments files for the model to predict travel time - Part 2

# %% [markdown]
# ### We are using Numpy to vectorize pandas functions on the large dataframes in order to improve performance

# %% [markdown]
# ## This workbook is continued from NumpyCreatingSegmentFile.ipynb

# %% [markdown]
# #### Reading the file generated by Part 1

# %%
columntype={
    "dayofservice":"category",
    "tripid":"uint32",
    "progrnumber":"uint8",
    "stoppointid":"category",
    "plannedtime_arr":"int32",
    "to_stop":"category",
    "to_stop_time":"int32"
}

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('final_stops_model_v5.csv',dtype=columntype)

# %%
# df[df['dayofservice'].str.contains('JUN')]
df.head()
# Out:
#          dayofservice   tripid  progrnumber stoppointid  actualtime_arr  \
# 0  02-JAN-16 00:00:00  2760214            1         324           79054
# 1  02-JAN-16 00:00:00  2760214            3        1635           79333
# 2  02-JAN-16 00:00:00  2760214            4        1636           79367
# 3  02-JAN-16 00:00:00  2760214            5        1637           79435
# 4  02-JAN-16 00:00:00  2760214            6        1638           79462
#
#    to_stop_time to_stop
# 0         79333    1635
# 1         79367    1636
# 2         79435    1637
# 3         79462    1638
# 4         79544     992

# %% [markdown]
# > **Adding school holidays**

# %%
# Converting school holidays as per the day of service provided in the data
school_holidays = ['2016-01-01','2016-01-04','2016-01-05','2016-02-15','2016-02-16','2016-02-17','2016-02-18','2016-02-19','2016-02-19','2016-03-16','2016-03-17','2016-03-18','2016-03-21','2016-03-22','2016-03-23','2016-03-24','2016-03-25','2016-03-28','2016-03-29','2016-03-30','2016-03-31','2016-04-01','2016-06-06','2016-06-07','2016-06-08','2016-06-09','2016-06-10','2016-06-13','2016-06-14','2016-06-15','2016-06-16','2016-06-17','2016-06-20','2016-06-21','2016-06-22','2016-06-23','2016-06-24','2016-06-27','2016-06-28','2016-06-29','2016-06-30','2017-01-02','2017-01-03','2017-01-04','2017-01-05','2017-01-06','2017-02-20','2017-02-21','2017-02-22','2017-02-23','2017-02-24','2017-04-09','2017-04-10','2017-04-11','2017-04-12','2017-04-13','2017-04-14','2017-04-16','2017-04-17','2017-04-18','2017-04-19','2017-04-20','2017-04-21','2017-06-05','2017-06-06','2017-06-07','2017-06-08','2017-06-09','2017-06-12','2017-06-13','2017-06-14','2017-06-15','2017-06-16','2017-06-19','2017-06-20','2017-06-21','2017-06-22','2017-06-23','2017-06-26','2017-06-27','2017-06-28','2017-06-29','2017-06-30']
import datetime as dt
# %d-%b-%y %H:%M:%S
dates_list = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in school_holidays]
dates_list_2 = [date.strftime('%d-%b-%y %H:%M:%S').upper() for date in dates_list]

# %%
df.loc[df.dayofservice.isin(dates_list_2),'is_school_holiday'] = 1
df.loc[~df.dayofservice.isin(dates_list_2),'is_school_holiday'] = 0

# %%
df['is_school_holiday'] = df['is_school_holiday'].astype('int')

# %%
df[df['is_school_holiday']==1].head()
# Out:
#            dayofservice   tripid  progrnumber stoppointid  actualtime_arr  \
# 315  01-JAN-16 00:00:00  2760234            1         324           71110
# 320  01-JAN-16 00:00:00  2760234            2        1634           71468
# 321  01-JAN-16 00:00:00  2760234            3        1635           71477
# 322  01-JAN-16 00:00:00  2760234            4        1636           71543
# 325  01-JAN-16 00:00:00  2760234            5        1637           71580
#
#      to_stop_time to_stop  is_school_holiday
# 315         71468    1634                  1
# 320         71477    1635                  1
# 321         71543    1636                  1
# 322         71580    1637                  1
# 325         71601    1638                  1

# %% [markdown]
# > **Calculating the travel time from the file below**

# %%
df['traveltime'] = df['to_stop_time'] - df['actualtime_arr']

# %%
df.head()
# Out:
#          dayofservice   tripid  progrnumber stoppointid  actualtime_arr  \
# 0  02-JAN-16 00:00:00  2760214            1         324           79054
# 1  02-JAN-16 00:00:00  2760214            3        1635           79333
# 2  02-JAN-16 00:00:00  2760214            4        1636           79367
# 3  02-JAN-16 00:00:00  2760214            5        1637           79435
# 4  02-JAN-16 00:00:00  2760214            6        1638           79462
#
#    to_stop_time to_stop  is_school_holiday  traveltime
# 0         79333    1635                  0         279
# 1         79367    1636                  0          34
# 2         79435    1637                  0          68
# 3         79462    1638                  0          27
# 4         79544     992                  0          82

# %% [markdown]
# > **Removing all those values which are less than 0**

# %%
df = df[df['traveltime']>0]

# %% [markdown]
# > **Getting the segment names for the segments**

# %%
df['segments'] = df['stoppointid'].astype(str)+'_'+df['to_stop'].astype(str)

# %%
df.dtypes
# Out:
# dayofservice         category
# tripid                 uint32
# progrnumber             uint8
# stoppointid          category
# actualtime_arr          int64
# to_stop_time            int32
# to_stop              category
# is_school_holiday       int32
# traveltime              int64
# segments               object
# dtype: object

# %%
df['traveltime'].std()
# Out:
# 96.91930172508243

# %%
df.head()
# Out:
#          dayofservice   tripid  progrnumber stoppointid  actualtime_arr  \
# 0  02-JAN-16 00:00:00  2760214            1         324           79054
# 1  02-JAN-16 00:00:00  2760214            3        1635           79333
# 2  02-JAN-16 00:00:00  2760214            4        1636           79367
# 3  02-JAN-16 00:00:00  2760214            5        1637           79435
# 4  02-JAN-16 00:00:00  2760214            6        1638           79462
#
#    to_stop_time to_stop  is_school_holiday  traveltime   segments
# 0         79333    1635                  0         279   324_1635
# 1         79367    1636                  0          34  1635_1636
# 2         79435    1637                  0          68  1636_1637
# 3         79462    1638                  0          27  1637_1638
# 4         79544     992                  0          82   1638_992

# %% [markdown]
# > Dropping the unwanted columns

# %%
df.drop(['tripid','progrnumber','stoppointid','to_stop','to_stop_time'],axis=1,inplace=True)

# %%
df.head()
# Out:
#          dayofservice  actualtime_arr  is_school_holiday  traveltime  \
# 0  02-JAN-16 00:00:00           79054                  0         279
# 1  02-JAN-16 00:00:00           79333                  0          34
# 2  02-JAN-16 00:00:00           79367                  0          68
# 3  02-JAN-16 00:00:00           79435                  0          27
# 4  02-JAN-16 00:00:00           79462                  0          82
#
#     segments
# 0   324_1635
# 1  1635_1636
# 2  1636_1637
# 3  1637_1638
# 4   1638_992

# %%
# df.to_csv('final_stops_model_v2.csv',index=False)

# %%
# sampling the data as per segment groups
# grouped = df.groupby('segments')

# %%
# df_sampled = grouped.apply(lambda x: x.sample(frac=0.5))

# %%
# len(df_sampled)

# %%
len(df)
# Out:
# 90270267

# %%
unique_vals = df.segments.unique()

# %%
len(unique_vals)
# Out:
# 92151

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:00001234@localhost:5433/jetaDb')

# %%
# Getting the list of segments and routes with the segments
df_routes_for_segment = pd.read_sql_query("select * from main_routes;",engine)
segmentids = []
routeids = []
segmentnos = []
from_stops=[]
to_stops=[]
for i, rows in df_routes_for_segment.iterrows():
    for j in range(len(rows['stopids'])):
        if j < (len(rows['stopids'])-1):
            segment = str(rows['stopids'][j])+"_"+str(rows['stopids'][j+1])
            from_stop = str(rows['stopids'][j])
            to_stop = str(rows['stopids'][j+1])
            segmentids.append(segment)
            segmentnos.append(j+1)
            routeids.append(rows['routeid'])
            from_stops.append(from_stop)
            to_stops.append(to_stop)
        else:
            break
df_journey = pd.DataFrame({'routeid':routeids,'segmentno':segmentnos,'segmentid':segmentids,'from_stop':from_stops,'to_stop':to_stops})

# %%
# Dropping all the duplicate segments -> Queueing Theory
df_journey.drop_duplicates(subset='segmentid',keep='first',inplace=True)

# %%
df_journey.reset_index(inplace=True,drop=True)

# %%
# df_segments = df[df['segments'].isin(df_journey['segmentid'].values)]

# %%
# len(df_segments)

# %%
# unique_df_seg = df.segments.unique()

# %%
# len(unique_df_seg)

# %% [markdown]
# #### Adding day of weeek

# %%
grouped = df.groupby('segments')

# %% [markdown]
# > Sampling the data by fraction of 30%

# %%
df_sampled = grouped.apply(lambda x: x.sample(frac=0.3))

# %% [markdown]
# > Adding day of week

# %%
df_sampled['dayofservice'] = pd.to_datetime(df_sampled['dayofservice'],format='%d-%b-%y %H:%M:%S',infer_datetime_format=True)

# %%
df_sampled['dayofweek'] = df_sampled['dayofservice'].dt.weekday_name

# %%
df_sampled['date'] = df_sampled['dayofservice'].dt.date

# %%
df_sampled['time'] = pd.to_datetime(df_sampled['actualtime_arr'],unit='s')

# %%
df_sampled['hour'] = df_sampled['time'].dt.hour

# %%
df_sampled.drop('time',axis=1,inplace=True)

# %%
df_sampled.drop('date',axis=1,inplace=True)

# %%
len(df_sampled.segments.unique())
# Out:
# 56250

# %% [markdown]
# > Adding rain

# %%
df_weather = pd.read_sql_query("SELECT concat_ws(' ', date::text, time::text) AS date, rain, temp FROM main_weather;",engine)

# %%
df_weather.head()
# Out:
#             date rain  temp
# 0  1/1/2016 0:00    0   1.2
# 1  1/1/2016 1:00    0   1.5
# 2  1/1/2016 2:00    0  -0.2
# 3  1/1/2016 3:00    0  -0.7
# 4  1/1/2016 4:00    0  -0.3

# %%
df_weather['date'] = pd.to_datetime(df_weather['date'],infer_datetime_format=True)

# %%
df_weather['dates'] = df_weather['date'].dt.date
df_weather['hour'] = df_weather['date'].dt.hour

# %%
df_weather.dtypes
# Out:
# date     datetime64[ns]
# rain             object
# temp             object
# dates            object
# hour              int64
# dtype: object

# %%
df_weather['dates'] = pd.to_datetime(df_weather['dates'],infer_datetime_format=True)

# %%
df_sampled.dtypes
# Out:
# dayofservice         datetime64[ns]
# actualtime_arr                int64
# is_school_holiday             int32
# traveltime                    int64
# segments                     object
# dayofweek                    object
# hour                          int64
# dtype: object

# %%
df_sampled_merged = df_sampled.merge(df_weather,left_on=['dayofservice','hour'],right_on=['dates','hour'],how='left')

# %%
df_sampled_merged.dtypes
# Out:
# dayofservice         datetime64[ns]
# actualtime_arr                int64
# is_school_holiday             int32
# traveltime                    int64
# segments                     object
# dayofweek                    object
# hour                          int64
# date                 datetime64[ns]
# rain                         object
# temp                         object
# dates                datetime64[ns]
# dtype: object

# %% [markdown]
# > Adding Holiday Info

# %%
# Adding Holiday Information
holidays_series = pd.read_sql_query("select date from main_bankholidays;",engine)

# %%
holidays_series['date'] = pd.to_datetime(holidays_series['date'],infer_datetime_format=True)

# %%
holidays_series
# Out:
#          date
# 0  2016-01-01
# 1  2016-03-06
# 2  2016-03-17
# 3  2016-03-25
# 4  2016-03-28
# 5  2016-05-02
# 6  2016-06-06
# 7  2016-06-19
# 8  2016-08-01
# 9  2016-10-31
# 10 2016-12-25
# 11 2016-12-26
# 12 2016-12-27
# 13 2016-12-28
# 14 2017-01-01
# 15 2017-01-02
# 16 2017-03-17
# 17 2017-03-26
# 18 2017-04-14
# 19 2017-04-17
# 20 2017-05-01
# 21 2017-06-05
# 22 2017-06-18
# 23 2017-08-07
# 24 2017-10-30
# 25 2017-12-25
# 26 2017-12-26
# 27 2017-12-27
# 28 2018-01-01
# 29 2018-03-11
# 30 2018-03-19
# 31 2018-03-30
# 32 2018-04-02
# 33 2018-05-07
# 34 2018-06-04
# 35 2018-06-17
# 36 2018-08-06
# 37 2018-10-29
# 38 2018-12-25
# 39 2018-12-26
# 40 2018-12-27

# %%
df_sampled_merged[df_sampled_merged['dayofservice']==pd.to_datetime('2016-01-01',infer_datetime_format=True)]
# Out:
#          dayofservice  actualtime_arr  is_school_holiday  traveltime  \
# 201        2016-01-01           85092                  1          16
# 373        2016-01-01           51622                  1          33
# 439        2016-01-01           67879                  1          34
# 692        2016-01-01           55171                  1          41
# 710        2016-01-01           60703                  1          18
# 1016       2016-01-01           79712                  1          19
# 1510       2016-01-01           39816                  1          14
# 1807       2016-01-01           44029                  1          18
# 1985       2016-01-01           57354                  1          21
# 2430       2016-01-01           49664                  1          19
# 2772       2016-01-01           78414                  1          19
# 3007       2016-01-01           72909                  1          20
# 3886       2016-01-01           57375                  1          62
# 4263       2016-01-01           74776                  1          32
# 4414       2016-01-01           69720                  1          42
# 4801       2016-01-01           71033                  1          40
# 5592       2016-01-01           78433                  1          64
# 7949       2016-01-01           60860                  1          80
# 8492       2016-01-01           68034                  1          90
# 8843       2016-01-01           47617                  1          27
# 8883       2016-01-01           64467                  1          80
# 8905       2016-01-01           73024                  1          25
# 9241       2016-01-01           78497                  1          58
# 9535       2016-01-01           71073                  1          67
# 9591       2016-01-01           74808                  1          29
# 10870      2016-01-01           60940                  1          30
# 10985      2016-01-01           53609                  1          27
# 10986      2016-01-01           76518                  1          20
# 11422      2016-01-01           36853                  1          24
# 11703      2016-01-01           39947                  1          24
# ...               ...             ...                ...         ...
# 27064665   2016-01-01           78863                  1          54
# 27064829   2016-01-01           79292                  1          57
# 27065318   2016-01-01           49644                  1         117
# 27065383   2016-01-01           72223                  1          72
# 27066315   2016-01-01           70943                  1           7
# 27066410   2016-01-01           55071                  1          32
# 27066972   2016-01-01           72813                  1           8
# 27067214   2016-01-01           53362                  1          27
# 27067256   2016-01-01           83476                  1          24
# 27068090   2016-01-01           65750                  1          26
# 27068185   2016-01-01           45891                  1           9
# 27068650   2016-01-01           67775                  1          24
# 27068876   2016-01-01           57251                  1          11
# 27069229   2016-01-01           69591                  1          25
# 27070064   2016-01-01           36623                  1          39
# 27071307   2016-01-01           39738                  1          53
# 27072167   2016-01-01           69616                  1          58
# 27072468   2016-01-01           83500                  1          26
# 27072631   2016-01-01           62408                  1          46
# 27073334   2016-01-01           62454                  1          28
# 27073369   2016-01-01           64249                  1          29
# 27073547   2016-01-01           36662                  1          24
# 27073561   2016-01-01           39791                  1          25
# 27074061   2016-01-01           86673                  1          24
# 27075044   2016-01-01           57301                  1          53
# 27075415   2016-01-01           42006                  1          24
# 27075418   2016-01-01           45925                  1          77
# 27075799   2016-01-01           74724                  1          28
# 27076294   2016-01-01           47485                  1          27
# 27076439   2016-01-01           85062                  1          30
#
#            segments dayofweek  hour                date rain temp      dates
# 201       1000_1001    Friday    23 2016-01-01 23:00:00  0.4  8.4 2016-01-01
# 373       1000_1001    Friday    14 2016-01-01 14:00:00  0.7  7.4 2016-01-01
# 439       1000_1001    Friday    18 2016-01-01 18:00:00  1.1  8.5 2016-01-01
# 692       1000_1001    Friday    15 2016-01-01 15:00:00  0.5  7.8 2016-01-01
# 710       1000_1001    Friday    16 2016-01-01 16:00:00    1  8.1 2016-01-01
# 1016      1000_1001    Friday    22 2016-01-01 22:00:00  0.8  8.5 2016-01-01
# 1510      1000_1001    Friday    11 2016-01-01 11:00:00    0  7.8 2016-01-01
# 1807      1000_1001    Friday    12 2016-01-01 12:00:00    0  8.1 2016-01-01
# 1985      1000_1001    Friday    15 2016-01-01 15:00:00  0.5  7.8 2016-01-01
# 2430      1000_1001    Friday    13 2016-01-01 13:00:00  0.7  7.2 2016-01-01
# 2772      1000_1001    Friday    21 2016-01-01 21:00:00  1.2  8.5 2016-01-01
# 3007      1000_1001    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 3886      1001_1002    Friday    15 2016-01-01 15:00:00  0.5  7.8 2016-01-01
# 4263      1001_1002    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 4414      1001_1002    Friday    19 2016-01-01 19:00:00  1.2  8.6 2016-01-01
# 4801      1001_1002    Friday    19 2016-01-01 19:00:00  1.2  8.6 2016-01-01
# 5592      1001_1002    Friday    21 2016-01-01 21:00:00  1.2  8.5 2016-01-01
# 7949      1002_1003    Friday    16 2016-01-01 16:00:00    1  8.1 2016-01-01
# 8492      1002_1003    Friday    18 2016-01-01 18:00:00  1.1  8.5 2016-01-01
# 8843      1002_1003    Friday    13 2016-01-01 13:00:00  0.7  7.2 2016-01-01
# 8883      1002_1003    Friday    17 2016-01-01 17:00:00  1.8  8.5 2016-01-01
# 8905      1002_1003    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 9241      1002_1003    Friday    21 2016-01-01 21:00:00  1.2  8.5 2016-01-01
# 9535      1002_1003    Friday    19 2016-01-01 19:00:00  1.2  8.6 2016-01-01
# 9591      1002_1003    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 10870     1003_1004    Friday    16 2016-01-01 16:00:00    1  8.1 2016-01-01
# 10985     1003_1004    Friday    14 2016-01-01 14:00:00  0.7  7.4 2016-01-01
# 10986     1003_1004    Friday    21 2016-01-01 21:00:00  1.2  8.5 2016-01-01
# 11422     1003_1004    Friday    10 2016-01-01 10:00:00    0  7.6 2016-01-01
# 11703     1003_1004    Friday    11 2016-01-01 11:00:00    0  7.8 2016-01-01
# ...             ...       ...   ...                 ...  ...  ...        ...
# 27064665   993_5060    Friday    21 2016-01-01 21:00:00  1.2  8.5 2016-01-01
# 27064829   993_5060    Friday    22 2016-01-01 22:00:00  0.8  8.5 2016-01-01
# 27065318   993_5060    Friday    13 2016-01-01 13:00:00  0.7  7.2 2016-01-01
# 27065383   993_5060    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 27066315    997_998    Friday    19 2016-01-01 19:00:00  1.2  8.6 2016-01-01
# 27066410    997_998    Friday    15 2016-01-01 15:00:00  0.5  7.8 2016-01-01
# 27066972    997_998    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 27067214    997_998    Friday    14 2016-01-01 14:00:00  0.7  7.4 2016-01-01
# 27067256    997_998    Friday    23 2016-01-01 23:00:00  0.4  8.4 2016-01-01
# 27068090    997_998    Friday    18 2016-01-01 18:00:00  1.1  8.5 2016-01-01
# 27068185    997_998    Friday    12 2016-01-01 12:00:00    0  8.1 2016-01-01
# 27068650    997_998    Friday    18 2016-01-01 18:00:00  1.1  8.5 2016-01-01
# 27068876    997_998    Friday    15 2016-01-01 15:00:00  0.5  7.8 2016-01-01
# 27069229    997_998    Friday    19 2016-01-01 19:00:00  1.2  8.6 2016-01-01
# 27070064    998_999    Friday    10 2016-01-01 10:00:00    0  7.6 2016-01-01
# 27071307    998_999    Friday    11 2016-01-01 11:00:00    0  7.8 2016-01-01
# 27072167    998_999    Friday    19 2016-01-01 19:00:00  1.2  8.6 2016-01-01
# 27072468    998_999    Friday    23 2016-01-01 23:00:00  0.4  8.4 2016-01-01
# 27072631    998_999    Friday    17 2016-01-01 17:00:00  1.8  8.5 2016-01-01
# 27073334   999_1000    Friday    17 2016-01-01 17:00:00  1.8  8.5 2016-01-01
# 27073369   999_1000    Friday    17 2016-01-01 17:00:00  1.8  8.5 2016-01-01
# 27073547   999_1000    Friday    10 2016-01-01 10:00:00    0  7.6 2016-01-01
# 27073561   999_1000    Friday    11 2016-01-01 11:00:00    0  7.8 2016-01-01
# 27074061   999_1000    Friday     0 2016-01-01 00:00:00    0  1.2 2016-01-01
# 27075044   999_1000    Friday    15 2016-01-01 15:00:00  0.5  7.8 2016-01-01
# 27075415   999_1000    Friday    11 2016-01-01 11:00:00    0  7.8 2016-01-01
# 27075418   999_1000    Friday    12 2016-01-01 12:00:00    0  8.1 2016-01-01
# 27075799   999_1000    Friday    20 2016-01-01 20:00:00  1.8  8.4 2016-01-01
# 27076294   999_1000    Friday    13 2016-01-01 13:00:00  0.7  7.2 2016-01-01
# 27076439   999_1000    Friday    23 2016-01-01 23:00:00  0.4  8.4 2016-01-01
#
# [57977 rows x 11 columns]

# %%
df_sampled_merged.loc[df_sampled_merged.dayofservice.isin(holidays_series['date'].values), 'dayofweek']='Sunday'

# %%
df_sampled_merged.drop(['dayofservice','hour','date','dates'],axis=1,inplace=True)

# %%
df_sampled_merged.head()
# Out:
#    actualtime_arr  is_school_holiday  traveltime   segments  dayofweek rain  \
# 0           79907                  0          17  1000_1001    Tuesday    0
# 1           64277                  0         220  1000_1001     Monday    0
# 2           63248                  0          36  1000_1001   Saturday    0
# 3           27858                  0          59  1000_1001  Wednesday    0
# 4           56554                  1          79  1000_1001    Tuesday    0
#
#    temp
# 0   2.9
# 1   9.3
# 2  12.8
# 3   8.1
# 4  17.2

# %%
# df_sampled_merged = df_sampled_merged[df_sampled_merged['traveltime']>0]

# %%
# df_sampled_merged[df_sampled_merged['traveltime']==0]

# %% [markdown]
# > Analysing the outliers and missing values

# %%
max(df_sampled_merged['traveltime'].values)
# Out:
# 19987

# %%
min(df_sampled_merged['traveltime'].values)
# Out:
# 1

# %%
df_sampled_merged.describe().T.to_csv('actualTimeArrivalDescription.csv')

# %%
import matplotlib.pyplot as plt
f,ax = plt.subplots(figsize=(8,8))
df_sampled_merged.boxplot(column='traveltime')
plt.savefig('Figures//actualtime_outliers.png',transparent=True)

# %%
df_sampled_merged.describe().T
# Out:
#                         count          mean           std      min      25%  \
# actualtime_arr     27076602.0  53406.369271  17486.338904  15998.0  38063.0
# is_school_holiday  27076602.0      0.250752      0.433446      0.0      0.0
# traveltime         27076602.0     71.787337     93.735687      1.0     33.0
#
#                        50%      75%      max
# actualtime_arr     53532.0  67477.0  94064.0
# is_school_holiday      0.0      1.0      1.0
# traveltime            52.0     84.0  19987.0

# %%
len(df_sampled_merged[df_sampled_merged['traveltime']>(84.0+(1.5*51))])
# Out:
# 1779841

# %%
df_travelTimelessthan25iqr = df_sampled_merged[df_sampled_merged['traveltime']<(33.0)]

# %%
df_travelTimelessthan25iqr.describe().T
# Out:
#                        count          mean           std      min      25%  \
# actualtime_arr     6572263.0  54859.259965  18771.697684  16391.0  38129.0
# is_school_holiday  6572263.0      0.254247      0.435437      0.0      0.0
# traveltime         6572263.0     22.007500      6.642429      1.0     17.0
#
#                        50%      75%      max
# actualtime_arr     54839.0  71261.0  94064.0
# is_school_holiday      0.0      1.0      1.0
# traveltime            22.0     28.0     32.0

# %%
df_sampled_merged['traveltime'].clip(lower=22.0, upper=(84.0+(1.5*51)),inplace=True)

# %%
df_sampled_merged.describe().T
# Out:
#                         count          mean           std      min      25%  \
# actualtime_arr     27076602.0  53406.369271  17486.338904  15998.0  38063.0
# is_school_holiday  27076602.0      0.250752      0.433446      0.0      0.0
# traveltime         27076602.0     64.311604     40.454098     22.0     33.0
#
#                        50%      75%      max
# actualtime_arr     53532.0  67477.0  94064.0
# is_school_holiday      0.0      1.0      1.0
# traveltime            52.0     84.0    160.5

# %%
import matplotlib.pyplot as plt
f,ax = plt.subplots(figsize=(8,8))
df_sampled_merged.boxplot(column='traveltime')
# plt.savefig('Figures//actualtime_wo_outliers.png',transparent=True)

# %%
df_sampled_merged.head()

# %%
df_sampled_merged.to_csv('Sampled_Data_actualTime.csv',index_label=False,index=False)

# %% [markdown]
# **This is the end of the notebook, the following code was written to make the final segmented file. This now will be done in a new notebook where in flags for city center, school holiday, distance values, kalman filter coefficient and gradient descent algorithm will be implemented and then the following segments will be generated in the last file**

# %%
# # for i, val in df_sampled_merged.groupby('segments'):
# #     val.to_csv('SegmentedSamples2_actual\\{}.csv'.format(i),header=False,index_label=False,index=False)

# # df_journey.head()

# _39A_segments = df_journey[df_journey['routeid'].str.startswith('39A')]['segmentid'].values.tolist()

# unique_39A_segments = list(set(_39A_segments))

# df_sampled_merged.dtypes

# len(df_sampled_merged[df_sampled_merged['segments'].isin(unique_39A_segments)])

# df_39A_segments = df_sampled_merged[df_sampled_merged['segments'].isin(unique_39A_segments)]['segments'].values.tolist()

# unq_39_test = list(set(df_39A_segments))

# len(unq_39_test)

# (unique_39A_segments.isin(unq_39_test))

# set(unique_39A_segments) - set(unq_39_test)

# df_sampled_merged[df_sampled_merged['segments'].str.contains('')]

# df_39A_segments_sampled = df_sampled_merged[df_sampled_merged['segments'].isin(unique_39A_segments)]

# df_39A_segments_sampled

# for i, val in df_39A_segments_sampled.groupby('segments'):
#     val.to_csv('SegmentedSamples2_actual\\39A_segments\\{}.csv'.format(i),header=False,index_label=False,index=False)

# %% [markdown]
# <hr>
